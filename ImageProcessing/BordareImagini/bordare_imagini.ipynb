# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
date = pd.read_csv("sample_bordare.csv",delimiter=",")
imagine = np.array(date.values.tolist())/255.0
#train_X = np.array([np.reshape(el,(28,28)) for el in train_X])
imagine = np.reshape(imagine[0],(28,28))
plt.imshow(imagine)

# %%
def pad_with(vector, pad_width, iaxis, kwargs):
    pad_value = kwargs.get('padder', 0)
    vector[:pad_width[0]] = pad_value
    if pad_width[1] != 0:                      # <-- the only change (0 indicates no padding)
        vector[-pad_width[1]:] = pad_value
        
plt.imshow(np.pad(imagine, ((7, 3), (0, 20)), pad_with, padder=1))

# %%
combinations = [(2,2),(3,1),(1,3),(4,0),(0,4)] # nr de pixeli cu care sa se bordeze Width-ul/Height-ul

# %%
for el,label in zip(train_X,train_Y):
	for i in combinations:
		for j in combinations:
			train_X_bordate.append(np.pad(el, (i, j), pad_with, padder=0.))
			train_Y_bordate.append(label)
